# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitipornJaiaue/it-s_me/blob/main/04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_name = '/content/drive/MyDrive/ศพฐ04/งง/4 Now.xlsx' # ชื่อไฟล์ xlsx
dfs = pd.ExcelFile(file_name) # คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names # คำสั่งเช็คว่าในไฟล์ xlsx มี seet ย่อย ในไฟล์ชื่อว่าอะไรบ้าง
# Out:
# ['Real']

# %%
# select sheet page by sheet name
Real = dfs.parse('Real')

# %%
Real
# Out:
#        ลำดับ      วันที่    เดือน  \
# 0          1    3 ม.ค.66   มกราคม
# 1          2    3 ม.ค.66   มกราคม
# 2          3    3 ม.ค.66   มกราคม
# 3          4    3 ม.ค.66   มกราคม
# 4          5    3 ม.ค.66   มกราคม
# ...      ...         ...      ...
# 20929  20930   28 ธ.ค.66  ธันวาคม
# 20930  20931   28 ธ.ค.66  ธันวาคม
# 20931  20932   28 ธ.ค.66  ธันวาคม
# 20932  20933   28 ธ.ค.66  ธันวาคม
# 20933  20934   28 ธ.ค.66  ธันวาคม
#
#                                              หน่วยราชการ   เพศ  \
# 0                                         สภ.หนองสองห้อง   ชาย
# 1                                         สภ.หนองสองห้อง   ชาย
# 2                                         สภ.หนองสองห้อง   ชาย
# 3                                         สภ.หนองสองห้อง   ชาย
# 4                                             สภ.บ้านแฮด  หญิง
# ...                                                  ...   ...
# 20929                       บริษัท แฟลช เอ็กซ์เพรส จำกัด   ชาย
# ...

# %%
print(Real.isnull().any()) # เช็คค่าว่าง Null
Real.head()
# Out:
# ลำดับ          False
# วันที่         False
# เดือน          False
# หน่วยราชการ    False
# เพศ            False
# เรื่อง         False
# ประเภทงาน      False
# จำนวน (คน)     False
# dtype: bool
#    ลำดับ    วันที่   เดือน     หน่วยราชการ   เพศ              เรื่อง  \
# 0      1  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย            ขออนุญาต
# 1      2  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย  บรรจุเข้ารับราชการ
# 2      3  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย  บรรจุเข้ารับราชการ
# 3      4  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย            ขออนุญาต
# 4      5  3 ม.ค.66  มกราคม      สภ.บ้านแฮด  หญิง            ขออนุญาต
#
#             ประเภทงาน  จำนวน (คน)
# 0            ขออนุญาต           1
# 1  ราชการ/รัฐวิสาหกิจ           1
# 2  ราชการ/รัฐวิสาหกิจ           1
# 3            ขออนุญาต           1
# 4            ขออนุญาต           1

# %%
Real.to_csv('PFSC04.csv', index=False)
