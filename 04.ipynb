# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitipornJaiaue/it-s_me/blob/main/04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_name = '/content/drive/MyDrive/ศพฐ04/04.xlsx' # ชื่อไฟล์ xlsx
dfs = pd.ExcelFile(file_name) # คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names # คำสั่งเช็คว่าในไฟล์ xlsx มี seet ย่อย ในไฟล์ชื่อว่าอะไรบ้าง
# Out:
# ['real']

# %%
# select sheet page by sheet name
real = dfs.parse('real')

# %%
real
# Out:
#        ลำดับ      วันที่    เดือน  \
# 0          1    3 ม.ค.66   มกราคม
# 1          2    3 ม.ค.66   มกราคม
# 2          3    3 ม.ค.66   มกราคม
# 3          4    3 ม.ค.66   มกราคม
# 4          5    3 ม.ค.66   มกราคม
# ...      ...         ...      ...
# 20930  20931   28 ธ.ค.66  ธันวาคม
# 20931  20932   28 ธ.ค.66  ธันวาคม
# 20932  20933   28 ธ.ค.66  ธันวาคม
# 20933  20934   28 ธ.ค.66  ธันวาคม
# 20934  20935   28 ธ.ค.66  ธันวาคม
#
#                                              หน่วยราชการ   เพศ        เรื่อง  \
# 0                                         สภ.หนองสองห้อง   ชาย      ขออนุญาต
# 1                                         สภ.หนองสองห้อง   ชาย     รับราชการ
# 2                                         สภ.หนองสองห้อง   ชาย     รับราชการ
# 3                                         สภ.หนองสองห้อง   ชาย      ขออนุญาต
# 4                                             สภ.บ้านแฮด  หญิง      ขออนุญาต
# ...                                                  ...   ...           ...
# 20930                       บริษัท แฟลช เอ็กซ์เพรส จำกัด   ชาย  พนักงานเอกชน
# 20931                       บริษัท แฟลช เอ็กซ์เพรส จำกัด   ชาย  พนักงานเอกชน
# 20932  บริษัท รักษาความปลอดภัย ฟีนิกซ์ เอส แอนด์ ซี จ...   ชาย          รปภ.
# 20933  บริษัท รักษาความปลอดภัย และจัดการทรัพย์สิน ที....   ชาย          รปภ.
# 20934                 บริษัท รักษาความปลอดภัยชุบศร จำกัด   ชาย          รปภ.
#
#                 ประเภทงาน  จำนวน (คน)
# 0                ขออนุญาต           1
# 1      ราชการ/รัฐวิสาหกิจ           1
# 2      ราชการ/รัฐวิสาหกิจ           1
# 3                ขออนุญาต           1
# 4                ขออนุญาต           1
# ...                   ...         ...
# 20930               เอกชน           1
# 20931               เอกชน           1
# 20932                รปภ.           1
# 20933                รปภ.           1
# 20934                รปภ.           1
#
# [20935 rows x 8 columns]

# %%
print(real.isnull().any()) # เช็คค่าว่าง Null
real.head()
# Out:
# ลำดับ          False
# วันที่         False
# เดือน          False
# หน่วยราชการ    False
# เพศ            False
# เรื่อง          True
# ประเภทงาน       True
# จำนวน (คน)     False
# dtype: bool
#    ลำดับ    วันที่   เดือน     หน่วยราชการ   เพศ     เรื่อง  \
# 0      1  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย   ขออนุญาต
# 1      2  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย  รับราชการ
# 2      3  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย  รับราชการ
# 3      4  3 ม.ค.66  มกราคม  สภ.หนองสองห้อง   ชาย   ขออนุญาต
# 4      5  3 ม.ค.66  มกราคม      สภ.บ้านแฮด  หญิง   ขออนุญาต
#
#             ประเภทงาน  จำนวน (คน)
# 0            ขออนุญาต           1
# 1  ราชการ/รัฐวิสาหกิจ           1
# 2  ราชการ/รัฐวิสาหกิจ           1
# 3            ขออนุญาต           1
# 4            ขออนุญาต           1
